# %% [markdown]
# import liabreries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Replace the file path with the correct one
file_path = r'C:/Users/Mohit Lahoti/Downloads/Compressed/Data-Science-ML-Capstone-Projects-master/Data-Science-ML-Capstone-Projects-master/baseball.csv'

# %%
# Read the CSV file
df = pd.read_csv(file_path)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# Display the DataFrame
print(df.head())
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
# Display the DataFrame
print(df.tail())
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#check null value by using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#cheking no.of unique values in each column
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
# checking the value counts of each column
for col in df.columns:
    print(df[col].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
# Checking for duplicate values
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# Creating an lmplot for W vs R
sns.lmplot(x='W',  y='R', data=df)
plt.show()

# %%
# Creating an lmplot for AB vs H
sns.lmplot(x='AB',  y='H', data=df)
plt.show()

# %%
# Creating an lmplot for 2B vs 3B
sns.lmplot(x='2B',  y='3B', data=df)
plt.show()

# %%
# Creating an lmplot for HR vs BB
sns.lmplot(x='HR',  y='BB', data=df)
plt.show()

# %%
# Creating an lmplot for age vs charges
sns.lmplot(x='SO',  y='SB', data=df)
plt.show()

# %%
# Creating an lmplot for age vs charges
sns.lmplot(x='RA',  y='ER', data=df)
plt.show()

# %%
# Creating an lmplot for age vs charges
sns.lmplot(x='ERA',  y='CG', data=df)
plt.show()

# %%
# Creating an lmplot for SHO VS SV
sns.lmplot(x='SHO',  y='SV', data=df)
plt.show()

# %%
# Creating an lmplot for SV VS E
sns.lmplot(x='SV',  y='E', data=df)
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p <=17:
        plt.subplot(5,4,p)
        sns.regplot(x='W', y=i, data=df, color='g')
        plt.xlabel("W")
        plt.ylabel(i)
        p+=1

plt.show()

# %%
# create a scatter plot for each numerical feature

plt.figure(figsize=(20, 15))
for i, col in enumerate(df.columns[:-1]):
    plt.subplot(4, 4, i + 1)
    plt.scatter(df[col], df['W'])
    plt.xlabel(col)
    plt.ylabel('W')
    plt.title(f'Scatter plot of {col} vs W')
plt.tight_layout()
plt.show()

# %%
# Creating a pair plot
sns.pairplot(df)

# %%
# Creating a line plot for 'charges'
plt.plot(df['W'])
sns.lineplot(data =df.iloc[:,:-1])
plt.ylabel('W')
plt.title('Base ball')
plt.show()

# %%
# Create box plots for each numeric column
plt.figure(figsize=(12, 6))
df.boxplot()
plt.title("Box Plots of Numeric Variables")
plt.xticks(rotation=45)
plt.show()

# %%
#remove outliers with z-score method
from scipy.stats import zscore
out_features = df
z = np.abs(zscore(out_features))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
#threshold value = 3
np.where (z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#data shape after removing outliers
df1 =df[(z<3).all(axis=1)]
df1.shape
# Out:
# (29, 17)

# %%
#shape of old and new data frame
print("old df_",df.shape[0])
print("New df_",df1.shape[0])
# Out:
# old df_ 30
# New df_ 29

# %%
#view data loss by persentage 
print("data loss percentage_",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage_ 3.3333333333333335

# %%
df=df1

# %%
# check skewness 
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
#lets check how the data hase been distributed in remaining column
import math

num_features = len(df.columns)
plot_cols = 4
plot_rows = math.ceil(num_features / plot_cols)

plt.figure(figsize=(15, 3 * plot_rows))

for i, col in enumerate(df.columns):
    plt.subplot(plot_rows, plot_cols, i+1)
    sns.histplot(df[col], kde=True, color='m', alpha=0.7)
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# apply cube root transformation to reduce skewness
for col in df:
    if df[col].skew() > 0.5:
        df[col] = np.cbrt(df[col])

# %%
#checking skewness again
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.753696
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -1.013981
# SHO   -0.298136
# SV     0.280963
# E      0.671748
# dtype: float64

# %%
#lets check skewness again
num_features = len(df.columns)
plot_cols = 4
plot_rows = math.ceil(num_features / plot_cols)

plt.figure(figsize=(15, 3 * plot_rows))

for i, col in enumerate(df.columns):
    plt.subplot(plot_rows, plot_cols, i+1)
    sns.histplot(df[col], kde=True, color='m', alpha=0.7)
    plt.xlabel(col)
    plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
cor=df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.019968  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432686  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769847  0.490752  0.445604 -0.064653
# H   -0.019968  0.432686  0.769847  1.000000  0.527588  0.580521 -0.219048
# 2B   0.384886  0.469293  0.490752  0.527588  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.580521  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219048 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.221951  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.372834 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.419443  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.243965 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280165 -0.224993  0.333731 -0.062094
# ...

# %%
# Create the heatmap
plt.figure(figsize=(10, 8))
ax = plt.gca()
sns.heatmap(cor, annot=True, cmap='coolwarm', ax=ax)
plt.title('Correlation Heatmap')
plt.show()

# %%
cor['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.755967
# SHO    0.468575
# BB     0.447513
# R      0.390451
# 2B     0.384886
# HR     0.245697
# SO     0.156469
# H     -0.019968
# CG    -0.026520
# E     -0.074272
# AB    -0.085780
# SB    -0.169503
# 3B    -0.206737
# ER    -0.815308
# RA    -0.823176
# ERA   -0.826952
# Name: W, dtype: float64

# %%
# Create a barplot of the correlation coefficients
plt.figure(figsize=(6,3))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar', color="m")
plt.xlabel('Features', fontsize=15)
plt.ylabel('Target', fontsize=15)          
plt.title("Correlation between features and target variable")
plt.show()

# %%
#separating features and label
x = df.drop('W',axis=1)
y = df['W']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df
# Out:
#       W    R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  724  5575  11.439506  300  42  139  383   973  104  641  601  3.73
# 1    83  696  5467  11.049365  277  44  156  439  1264   70  700  653  4.07
# 2    81  669  5439  11.173556  303  29  141  533  1157   86  640  584  3.67
# 3    76  622  5533  11.136051  260  27  136  404  1231   68  701  643  3.98
# 4    74  689  5605  11.485173  289  49  151  455  1259   83  803  746  4.64
# 6    87  764  5567  11.178893  272  19  212  554  1227   63  698  652  4.03
# 7    81  713  5485  11.106405  246  20  217  418  1331   44  693  646  4.05
# 8    80  644  5485  11.141425  278  32  167  436  1310   87  642  604  3.74
# 9    78  748  5640  11.434409  294  33  161  478  1148   71  753  694  4.31
# 10   88  751  5511  11.237270  279  32  172  503  1233  101  733  680  4.24
# 11   86  729  5459  11.087457  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor


# Calculate VIF for each feature
df_with_constant = sm.add_constant(df)
vif = pd.DataFrame()
vif["Feature"] = df_with_constant.columns
vif["VIF"] = [variance_inflation_factor(df_with_constant.values, i) for i in range(df_with_constant.shape[1])]
print(vif)
# Out:
#    Feature           VIF
# 0    const  67043.609552
# 1        W     18.306213
# 2        R     13.126541
# 3       AB     19.924276
# 4        H      9.798556
# 5       2B      4.283378
# 6       3B      3.133555
# 7       HR      8.925109
# 8       BB      3.656174
# 9       SO      2.776048
# 10      SB      1.987684
# 11      RA    199.271468
# 12      ER   2006.996448
# 13     ERA   1731.713439
# 14      CG      3.050058
# 15     SHO      3.200534
# 16      SV      6.888530
# 17       E      2.113525

# %%
#value count in target variable
target_counts = df['W'].value_counts()
print(target_counts)
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 97     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 95     1
# 98     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# # modelling¶

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
#finding the best random state

MaxAccu = 0
MaxRs = 0

for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    rf = RandomForestRegressor()
    rf.fit(x_train, y_train)
    pred = rf.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRs = i

print("Maximum R2 score is", MaxAccu, "on Random State", MaxRs)
# Out:
# Maximum R2 score is 0.8618145087085115 on Random State 129

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=129)

# %%
#import liabraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
pred_lr = lr.predict(x_test)
pred_train = lr.predict(x_train)

print("R2_score:",r2_score(y_test,pred_lr))
print("R2_score on training Data:",r2_score(y_train,pred_train)*100)
print ("MeanAbsoluteError:",mean_absolute_error(y_test,pred_lr))
print ("MeanSquaredError:",mean_squared_error(y_test,pred_lr))
print ("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2_score: 0.03419652403799445
# R2_score on training Data: 97.32554968629856
# MeanAbsoluteError: 7.438883205222183
# MeanSquaredError: 72.566419193886
# Root Mean Squared Error: 8.518592559448187

# %%
Rd = Ridge()
Rd.fit(x_train, y_train)
pred_Rd = Rd.predict(x_test)
pred_train = Rd.predict(x_train)

print("R2_score:", r2_score(y_test, pred_Rd))
print("R2_score on training Data:", r2_score(y_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_test, pred_Rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_Rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_Rd)))
# Out:
# R2_score: 0.5150169396787461
# R2_score on training Data: 0.9086935077809261
# Mean Absolute Error: 4.802448463520806
# Mean Squared Error: 36.439591421174704
# Root Mean Squared Error: 6.036521466968763

# %%
Ls= Lasso()
Ls.fit(x_train, y_train)
pred_Ls = Ls.predict(x_test)
pred_train = Ls.predict(x_train)

print("R2_score:", r2_score(y_test, pred_Ls))
print("R2_score on training Data:", r2_score(y_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_test, pred_Ls))
print("Mean Squared Error:", mean_squared_error(y_test, pred_Ls))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_Ls)))
# Out:
# R2_score: 0.46461410943005566
# R2_score on training Data: 0.8783555261056789
# Mean Absolute Error: 4.830246123843523
# Mean Squared Error: 40.226648518625694
# Root Mean Squared Error: 6.3424481486745865

# %%
Dtr = DecisionTreeRegressor()
Dtr.fit(x_train, y_train)
pred_Dtr = Dtr.predict(x_test)
pred_train = Dtr.predict(x_train)

print("R2_score:", r2_score(y_test, pred_Dtr))
print("R2_score on training Data:", r2_score(y_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_test, pred_Dtr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_Dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_Dtr)))
# Out:
# R2_score: 0.41587249424909634
# R2_score on training Data: 1.0
# Mean Absolute Error: 5.222222222222222
# Mean Squared Error: 43.888888888888886
# Root Mean Squared Error: 6.624868971450597

# %%
Rfr = RandomForestRegressor()
Rfr.fit(x_train, y_train)
pred_Rfr = Rfr.predict(x_test)
pred_train = Rfr.predict(x_train)

print("R2_score:", r2_score(y_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_test, pred_Rfr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_Rfr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_Rfr)))
# Out:
# R2_score: 0.837561830430496
# R2_score on training Data: 0.9359060684658421
# Mean Absolute Error: 2.9144444444444466
# Mean Squared Error: 12.204922222222235
# Root Mean Squared Error: 3.4935543823192785

# %%
Svr = SVR()
Svr.fit(x_train, y_train)
pred_Svr = Svr.predict(x_test)
pred_train = Svr.predict(x_train)

print("R2_score:", r2_score(y_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_test, pred_Svr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_Svr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_Svr)))
# Out:
# R2_score: 0.837561830430496
# R2_score on training Data: 0.0008198503840229909
# Mean Absolute Error: 7.158235923253143
# Mean Squared Error: 75.88957834724201
# Root Mean Squared Error: 8.711462468910831

# %%
Knn = KNeighborsRegressor()
Knn.fit(x_train, y_train)
pred_Knn = Knn.predict(x_test)
pred_train = Knn.predict(x_train)

print("R2_score:", r2_score(y_test, pred_Knn))
print("R2_score on training Data:", r2_score(y_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_test, pred_Knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_Knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_Knn)))
# Out:
# R2_score: 0.5084456128820244
# R2_score on training Data: 0.4997920730530966
# Mean Absolute Error: 4.48888888888889
# Mean Squared Error: 36.93333333333333
# Root Mean Squared Error: 6.077280093375105

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_lr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.58699093 -0.46549027  0.6121954  -0.44887839 -0.95455094]
# Mean Cross Validation Score: -0.13394665309968762
# Difference between R2 score and Cross Validation score: 16.814317713768208

# %%
scores = cross_val_score(Rd, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_Rd) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.33286644 -1.22696401  0.48707907  0.79985     0.09570211]
# Mean Cross Validation Score: 0.09770672279948042
# Difference between R2 score and Cross Validation score: 55.38980981877608

# %%
scores = cross_val_score(Ls, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_Ls) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.30732918 -1.49505275  0.46771395  0.78155254  0.51943659]
# Mean Cross Validation Score: 0.11619590083482971
# Difference between R2 score and Cross Validation score: 46.26795182730287

# %%
scores = cross_val_score(Dtr, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_Dtr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-1.56022727 -9.03947368  0.300711    0.27377049  0.36910377]
# Mean Cross Validation Score: -1.93122313839357
# Difference between R2 score and Cross Validation score: 195.41450527512526

# %%
scores = cross_val_score(Rfr, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_Rfr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.12842773 -4.62507632  0.44305445  0.43773377  0.86406574]
# Mean Cross Validation Score: -0.5503589241794306
# Difference between R2 score and Cross Validation score: 138.79207546099266

# %%
scores = cross_val_score(Svr, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.14625029 -1.25790554 -0.06355488 -0.64188774 -0.03413901]
# Mean Cross Validation Score: -0.42874749206072604
# Difference between R2 score and Cross Validation score: 41.8715312283105

# %%
scores = cross_val_score(Knn, x, y, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_test, pred_Knn) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.65572727 -2.62052632  0.37716437  0.25554098  0.78667453]
# Mean Cross Validation Score: -0.3713747420468805
# Difference between R2 score and Cross Validation score: 87.98203549289049

# %% [markdown]
# our best fit model is Rfr(Random Forest Regressor)

# %%
#GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300],  
    'max_depth': [5, 10, 15],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],  
    'random_state': [1, 4, 10, 20],  
}


rf_regressor = RandomForestRegressor()
grid_search = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, cv=5)
grid_search.fit(x_train, y_train)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 20}
# Best Score: 0.43026492517852466

# %%
Model = RandomForestRegressor(max_depth = 5, min_samples_leaf = 2, min_samples_split = 2, n_estimators = 100, random_state = 20)

# %%
Model.fit(x_train,y_train)
pred = Model.predict(x_test)
print("R2_Score:",r2_score(y_test,pred))
print("MeanAbsoluteError:",mean_absolute_error(y_test,pred))
print("MeanSquaredError:",mean_squared_error(y_test,pred))
print("Root_Mean_Squared_Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.8286034849902255
# MeanAbsoluteError: 2.8240767195767122
# MeanSquaredError: 12.878014695672691
# Root_Mean_Squared_Error: 3.588595086614355

# %%
import pickle

Filename = "BaseballCaseStudy.pkl"
pickle.dump(Model,open(Filename,'wb'))

# %%
loadedModel = pickle.load(open('BaseballCaseStudy.pkl','rb'))
result = loadedModel.score(x_test,y_test)
print(result*100)
# Out:
# 82.86034849902255

# %%
Conclusion = pd.DataFrame([loadedModel.predict(x_test)[:],y_test[:]],index = ["predicted","original"])
Conclusion
# Out:
#                   0          1          2          3          4       5  \
# predicted  92.52206  72.647595  75.144357  85.144881  79.923357  83.599
# original   98.00000  76.000000  68.000000  87.000000  76.000000  83.000
#
#                    6          7          8
# predicted  91.686131  72.750524  81.128905
# original   90.000000  74.000000  81.000000
