# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
## Read the CSV file with a different encoding
df1 = pd.read_csv(r"C:\Users\Mohit Lahoti\Downloads\Compressed\zomato.csv", encoding='latin1')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2 = pd.read_excel(r"C:\Users\Mohit Lahoti\Downloads\Compressed\Country-Code.xlsx")

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# Merge the datasets on the country code
df = pd.merge(df1, df2, on="Country Code")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#check null value by using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#cheking no.of unique values in each column
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
# checking the value counts of each column
for col in df.columns:
    print(df[col].value_counts())
    print('\n')
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# ...

# %%
# Checking for duplicate values
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Setting Restaurant Id as Data Frame index
df.set_index("Restaurant ID", inplace=True)

# %%
df
# Out:
#                         Restaurant Name  Country Code              City  \
# Restaurant ID
# 6317637                Le Petit Souffle           162       Makati City
# 6304287                Izakaya Kikufuji           162       Makati City
# 6300002          Heat - Edsa Shangri-La           162  Mandaluyong City
# 6318506                            Ooma           162  Mandaluyong City
# 6314302                     Sambo Kojin           162  Mandaluyong City
# ...                                 ...           ...               ...
# 5915730                    NamlÛ± Gurme           208         ÛÁstanbul
# 5908749                   Ceviz AÛôacÛ±           208         ÛÁstanbul
# 5915807                           Huqqa           208         ÛÁstanbul
# 5916112                    Aôôk Kahve           208         ÛÁstanbul
# 5927402        Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                          Address  \
# Restaurant ID
# ...

# %%
# Separate columns by data type
numerical_cols = ['Country Code','Longitude', 'Latitude', 'Average Cost for two', 
                  'Price range', 'Aggregate rating', 'Votes', ]
num_df = df[numerical_cols]

# %%
categorical_cols = ['Restaurant Name','City','Address','Locality','Locality Verbose',
                   'Cuisines','Currency','Has Table booking','Has Online delivery',
                   'Is delivering now','Switch to order menu','Rating color','Rating text',
                    'Country']
cat_df = df[categorical_cols]

# %%
description = num_df.describe()
description
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9551.000000  9551.000000  9551.000000           9551.000000
# mean      18.365616    64.126574    25.854381           1199.210763
# std       56.750546    41.467058    11.007935          16121.183073
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081343    28.478713            250.000000
# 50%        1.000000    77.191964    28.570469            400.000000
# 75%        1.000000    77.282006    28.642758            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9551.000000       9551.000000   9551.000000
# mean      1.804837          2.666370    156.909748
# std       0.905609          1.516378    430.169145
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# ...

# %% [markdown]
# Univarient analysis

# %%
# for target columns ('Average Cost for two','Price range')
# Average Cost for two
plt.figure(figsize=(8, 6))
sns.countplot(x='Average Cost for two', data=df)
plt.title('Average Cost for two Count')
plt.xlabel('Average Cost for two')
plt.ylabel('Count')
plt.show()

# %%
#Price range
plt.figure(figsize=(8, 6))
plt.hist(df['Price range'], bins=10, edgecolor='black')
plt.title('Price range Distribution')
plt.xlabel('Price range')
plt.ylabel('Frequency')
plt.show()

# %%
#Average Cost for two
plt.figure(figsize=(8, 6))
plt.hist(df['Average Cost for two'], bins=10, edgecolor='black')
plt.title('Average Cost for two Distribution')
plt.xlabel('Average Cost for two')
plt.ylabel('Frequency')
plt.show()

# %%
#Price range
plt.figure(figsize=(8, 6))
sns.countplot(x='Price range', data=df)
plt.title('Price range')
plt.xlabel('Price range')
plt.ylabel('Count')
plt.show()

# %%
# for numerical columns
plt.figure(figsize=(8, 15))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(7, 1, i)
    sns.histplot(df[col], kde=True)
    plt.xlabel(col)
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# for categorical columns
plt.figure(figsize=(12, 18))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(7, 2, i)
    sns.countplot(x=col, data=df)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
# Relationship between Average Cost for two and numerical columns
N_col = ['Country Code','Longitude', 'Latitude',  'Price range', 
         'Aggregate rating', 'Votes', ]
plt.figure(figsize=(8, 8))
for i, col in enumerate(N_col, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x='Average Cost for two', y=col, data=df)
    plt.xlabel('Average Cost for two')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
# Relationship between Price range and numerical columns
n_col = ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Aggregate rating', 'Votes']

plt.figure(figsize=(10, 12))
for i, col in enumerate(n_col, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x='Price range', y=col, data=df)
    plt.xlabel('Price range')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
# Relationship between Average Cost for two, Latitude, and Longitude
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Latitude', y='Longitude', hue='Average Cost for two', data=df)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Average Cost for two vs Latitude vs Longitude')
plt.show()

# %%
# Relationship between Average Cost for two, Price range, and Aggregate rating
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Price range', y='Aggregate rating', hue='Average Cost for two', data=df)
plt.xlabel('Price range')
plt.ylabel('Aggregate rating')
plt.title('Average Cost for two vs Price range vs Aggregate rating')
plt.show()

# %%
# Relationship between Price range, Average Cost for two, and Votes
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Average Cost for two', y='Votes', hue='Price range', data=df)
plt.xlabel('Average Cost for two')
plt.ylabel('Votes')
plt.title('Price range vs Average Cost for two vs Votes')
plt.show()

# %%
#check for outliers
df_outliers = df[numerical_cols]
df_outliers.plot(kind='box', subplots=True, layout=(7, 4), fontsize=10, figsize=(12, 18))
plt.show()

# %%
#remove outliers with z-score method
from scipy.stats import zscore
out_df = df[numerical_cols]
z = np.abs(zscore(out_df))
z
# Out:
#                Country Code  Longitude  Latitude  Average Cost for two  \
# Restaurant ID
# 6317637            2.531111   1.372269  1.025581              0.006154
# 6304287            2.531111   1.371945  1.026647              0.000049
# 6300002            2.531111   1.372975  1.024131              0.173743
# 6318506            2.531111   1.372966  1.023775              0.018659
# 6314302            2.531111   1.372991  1.023854              0.018659
# ...                     ...        ...       ...                   ...
# 5915730            3.341718   0.847685  1.378025              0.069428
# 5908749            3.341718   0.846144  1.376849              0.067878
# 5915807            3.341718   0.846305  1.381025              0.063845
# 5916112            3.341718   0.846272  1.381221              0.066947
# 5927402            3.341718   0.846513  1.374571              0.070979
#
#                Price range  Aggregate rating     Votes
# Restaurant ID
# ...

# %%
#threshold value = 3
z_score_threshold = 3

# %%
outliers = np.any(z > z_score_threshold, axis=1)

# %%
df_out = df[~outliers]

# %%
df_out.shape
# Out:
# (8565, 21)

# %%
#shape of old and new data frame
print("old df_",df.shape[0])
print("New df_",df_out.shape[0])
# Out:
# old df_ 9551
# New df_ 8565

# %%
#view data loss by persentage 
print("data loss percentage_",((df.shape[0]-df_out.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage_ 10.323526332321222

# %%
df=df_out

# %%
# check skewness 
df.skew()
# Out:
# Country Code            11.593933
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two     3.718671
# Price range              1.029231
# Aggregate rating        -0.877262
# Votes                    3.653843
# dtype: float64

# %%
#lets check how the data hase been distributed in numerical columns
plt.figure(figsize=(10, 18))  
plotnumber = 1
for col in numerical_cols:
    if plotnumber <=7:
        plt.subplot(7, 1, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# apply cube root transformation to reduce skewness
for col in numerical_cols:
    if df[col].skew() > 0.5:
        df[col] = np.cbrt(df[col])

# %%
#checking skewness again
df.skew()
# Out:
# Country Code            11.542592
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two     1.044058
# Price range              0.614188
# Aggregate rating        -0.877262
# Votes                    0.761689
# dtype: float64

# %%
#lets check again how the data hase been distributed in numerical columns
plt.figure(figsize=(10, 18))  
plotnumber = 1
for col in numerical_cols:
    if plotnumber <= 7:
        plt.subplot(7, 1, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# Encode categorical columns using Ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder

OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))


df
# Out:
#                Restaurant Name  Country Code  City  Address  Locality  \
# Restaurant ID
# 6317637                 3321.0      5.451362  27.0   7731.0      98.0
# 6304287                 2794.0      5.451362  27.0   5244.0     376.0
# 6300002                 2550.0      5.451362  28.0   3955.0     185.0
# 6318506                 4150.0      5.451362  28.0   7736.0     549.0
# 6314302                 4878.0      5.451362  28.0   7735.0     549.0
# ...                        ...           ...   ...      ...       ...
# 6201972                 1947.0      5.495865  13.0   1344.0     717.0
# 6201130                 6352.0      5.495865  13.0    835.0     736.0
# 18261203                4824.0      5.495865  13.0   4700.0     742.0
# 6201360                 4253.0      5.495865  13.0   3211.0     759.0
# 18318801                4767.0      5.495865  13.0   7592.0     759.0
#
#                Locality Verbose   Longitude   Latitude  Cuisines  \
# Restaurant ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8565 entries, 6317637 to 18318801
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       8565 non-null   float64
#  1   Country Code          8565 non-null   float64
#  2   City                  8565 non-null   float64
#  3   Address               8565 non-null   float64
#  4   Locality              8565 non-null   float64
#  5   Locality Verbose      8565 non-null   float64
#  6   Longitude             8565 non-null   float64
#  7   Latitude              8565 non-null   float64
#  8   Cuisines              8565 non-null   float64
#  9   Average Cost for two  8565 non-null   float64
#  10  Currency              8565 non-null   float64
#  11  Has Table booking     8565 non-null   float64
#  12  Has Online delivery   8565 non-null   float64
#  13  Is delivering now     8565 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      8565.000000   8565.000000  8565.000000  8565.000000  8565.000000
# mean       3221.416462      1.033379    31.272504  4047.393812   435.068768
# std        1890.117626      0.387891     8.574998  2285.052237   210.281142
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1577.000000      1.000000    35.000000  2076.000000   253.000000
# 50%        3165.000000      1.000000    35.000000  4103.000000   442.000000
# 75%        4841.000000      1.000000    35.000000  6015.000000   604.000000
# max        6572.000000      5.687734    54.000000  7947.000000   811.000000
#
#        Locality Verbose    Longitude     Latitude     Cuisines  \
# count       8565.000000  8565.000000  8565.000000  8565.000000
# mean         454.718272    72.930154    26.354364   723.488149
# std          226.575646    18.379620     7.104211   399.931587
# ...

# %%
# check correlation 
cor = df.corr()
cor
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.012263  0.008530  0.001829
# Country Code                 0.012263      1.000000  0.022649 -0.022569
# City                         0.008530      0.022649  1.000000 -0.095810
# Address                      0.001829     -0.022569 -0.095810  1.000000
# Locality                     0.008659     -0.029070 -0.029670  0.150581
# Locality Verbose             0.008637     -0.028382 -0.033822  0.152337
# Longitude                    0.016053      0.100252  0.036121 -0.017527
# Latitude                     0.012006     -0.157535  0.046024  0.010502
# Cuisines                     0.060831     -0.020453  0.014873 -0.016180
# Average Cost for two         0.058539     -0.025576 -0.084334  0.017810
# Currency                     0.000797     -0.212243 -0.134651  0.011598
# Has Table booking            0.041460      0.028481 -0.002165 -0.010811
# ...

# %%
# Visualizing the correlation by plotting a heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot=True, cmap="Blues")
plt.yticks(rotation=0)
plt.show()

# %%
# Drop columns
col_drop = ['Locality','Switch to order menu']
df.drop(col_drop, axis=1, inplace=True)

# %% [raw]
#  we drop 2 columns because 'Locality' and 'Localityverbose' has same value contain. and 'switch to order' menu contain same value for all raws

# %%
# check again correlation 
cor = df.corr()
cor
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.012263  0.008530  0.001829
# Country Code                 0.012263      1.000000  0.022649 -0.022569
# City                         0.008530      0.022649  1.000000 -0.095810
# Address                      0.001829     -0.022569 -0.095810  1.000000
# Locality Verbose             0.008637     -0.028382 -0.033822  0.152337
# Longitude                    0.016053      0.100252  0.036121 -0.017527
# Latitude                     0.012006     -0.157535  0.046024  0.010502
# Cuisines                     0.060831     -0.020453  0.014873 -0.016180
# Average Cost for two         0.058539     -0.025576 -0.084334  0.017810
# Currency                     0.000797     -0.212243 -0.134651  0.011598
# Has Table booking            0.041460      0.028481 -0.002165 -0.010811
# Has Online delivery          0.031505     -0.053182 -0.017478 -0.008224
# ...

# %%
# Visualizing the correlation by plotting a heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot=True, cmap="Blues")
plt.yticks(rotation=0)
plt.show()

# %%
#visulaizing the correlation  between label and features using bar plot 
#Average Cost for two
plt.figure(figsize=(22, 7))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar', color='magenta')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title('Correlation between Features and Label', fontsize=20)
plt.show()

# %%
#visulaizing the correlation  between label and features using bar plot 
#Price range
plt.figure(figsize=(22, 7))
df.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar', color='magenta')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title('Correlation between Features and Label', fontsize=20)
plt.show()

# %% [markdown]
# FIRST WE DO REGRESSION TASK (Average Cost for two)

# %%
#Separating features and label
X_reg = df.drop("Average Cost for two",axis=1)
y_reg= df["Average Cost for two"]

# %%
#Feature Scalling using standard scalarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_reg = pd.DataFrame(scaler.fit_transform(X_reg), columns=X_reg.columns)
X_reg
# Out:
#       Restaurant Name  Country Code      City   Address  Locality Verbose  \
# 0            0.052689     11.390428 -0.498280  1.612139         -1.570067
# 1           -0.226145     11.390428 -0.498280  0.523697         -0.312136
# 2           -0.355245     11.390428 -0.381656 -0.040436         -1.163998
# 3            0.491312     11.390428 -0.381656  1.614327          0.473520
# 4            0.876496     11.390428 -0.381656  1.613889          0.473520
# ...               ...           ...       ...       ...               ...
# 8560        -0.674292     11.505165 -2.131029 -1.183147          1.391589
# 8561         1.656387     11.505165 -2.131029 -1.405912          1.475451
# 8562         0.847925     11.505165 -2.131029  0.285615          1.501934
# 8563         0.545809     11.505165 -2.131029 -0.366050          1.585796
# 8564         0.817766     11.505165 -2.131029  1.551305          1.585796
#
#       Longitude  Latitude  Cuisines   Currency  Has Table booking  \
# ...

# %%
#checking again variance inflation factor (vif)
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif = pd.DataFrame()
Vif['VIF Values'] = [variance_inflation_factor(X_reg.values, i) for i in range(len(X_reg.columns))]
Vif['Features'] = X_reg.columns
Vif
# Out:
#     VIF Values             Features
# 0     1.009667      Restaurant Name
# 1    16.860429         Country Code
# 2     1.081637                 City
# 3     1.056954              Address
# 4     1.055983     Locality Verbose
# 5     8.654494            Longitude
# 6     8.834487             Latitude
# 7     1.026023             Cuisines
# 8     1.597249             Currency
# 9     1.518984    Has Table booking
# 10    1.205391  Has Online delivery
# 11    1.014840    Is delivering now
# 12    1.908933          Price range
# 13    3.479721     Aggregate rating
# 14    1.241421         Rating color
# 15    1.516806          Rating text
# 16    3.510042                Votes
# 17   16.848550              Country

# %% [raw]
# Multicollinearity is present but now we can't drop any columns

# %%
y_reg.value_counts()
# Out:
# 7.937005     890
# 6.694330     888
# 7.368063     848
# 5.848035     677
# 8.434327     645
#             ...
# 15.396817      1
# 16.868653      1
# 8.962809       1
# 19.129312      1
# 5.428835       1
# Name: Average Cost for two, Length: 93, dtype: int64

# %% [markdown]
# modelling for regression

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding the best random state

MaxAccu = 0
MaxRs = 0

for i in range(1, 200):
    X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg, y_reg, test_size=0.3, random_state=i)
    lr = LinearRegression()
    lr.fit(X_reg_train, y_reg_train)
    pred = lr.predict(X_reg_test)
    acc = r2_score(y_reg_test, pred)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRs = i

print("Maximum R2 score is", MaxAccu, "on Random State", MaxRs)
# Out:
# Maximum R2 score is 0.8298495652995097 on Random State 84

# %%
X_reg_train, X_reg_test, y_reg_train,y_reg_test = train_test_split(X_reg, y_reg, test_size=0.3, random_state=84)

# %%
#modelling
#import liabraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
lr.fit(X_reg_train,y_reg_train)
pred_lr = lr.predict(X_reg_test)
pred_train = lr.predict(X_reg_train)

print("R2_score:",r2_score(y_reg_test,pred_lr))
print("R2_score on training Data:",r2_score(y_reg_train,pred_train)*100)
print ("MeanAbsoluteError:",mean_absolute_error(y_reg_test,pred_lr))
print ("MeanSquaredError:",mean_squared_error(y_reg_test,pred_lr))
print ("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_reg_test,pred_lr)))
# Out:
# R2_score: 0.8298495652995097
# R2_score on training Data: 80.79199973195816
# MeanAbsoluteError: 0.668249149502976
# MeanSquaredError: 0.73252872476863
# Root Mean Squared Error: 0.8558789194556844

# %%
Rd = Ridge()
Rd.fit(X_reg_train, y_reg_train)
pred_Rd = Rd.predict(X_reg_test)
pred_train = Rd.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rd))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Rd))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Rd)))
# Out:
# R2_score: 0.8298639530507732
# R2_score on training Data: 80.79198888760432
# Mean Absolute Error: 0.6681636214312541
# Mean Squared Error: 0.7324667828693695
# Root Mean Squared Error: 0.8558427325562621

# %%
Dtr = DecisionTreeRegressor()
Dtr.fit(X_reg_train, y_reg_train)
pred_Dtr = Dtr.predict(X_reg_test)
pred_train = Dtr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Dtr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Dtr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Dtr)))
# Out:
# R2_score: 0.7642488513746655
# R2_score on training Data: 1.0
# Mean Absolute Error: 0.6985183931557939
# Mean Squared Error: 1.0149517899806955
# Root Mean Squared Error: 1.007448157465532

# %%
Rfr = RandomForestRegressor()
Rfr.fit(X_reg_train, y_reg_train)
pred_Rfr = Rfr.predict(X_reg_test)
pred_train = Rfr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Rfr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Rfr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Rfr)))
# Out:
# R2_score: 0.8853853080570264
# R2_score on training Data: 98.30225017166356
# Mean Absolute Error: 0.5278486609385158
# Mean Squared Error: 0.4934372003017509
# Root Mean Squared Error: 0.7024508525881017

# %%
Svr = SVR()
Svr.fit(X_reg_train, y_reg_train)
pred_Svr = Svr.predict(X_reg_test)
pred_train = Svr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Svr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Svr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Svr)))
# Out:
# R2_score: 0.8853853080570264
# R2_score on training Data: 84.52541937439915
# Mean Absolute Error: 0.599924383728621
# Mean Squared Error: 0.6425952675946015
# Root Mean Squared Error: 0.8016204011841275

# %%
Knn = KNeighborsRegressor()
Knn.fit(X_reg_train, y_reg_train)
pred_Knn = Knn.predict(X_reg_test)
pred_train = Knn.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Knn))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Knn))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Knn)))
# Out:
# R2_score: 0.7691101123834453
# R2_score on training Data: 83.96381143833015
# Mean Absolute Error: 0.7325237133277167
# Mean Squared Error: 0.9940231727027125
# Root Mean Squared Error: 0.997007107649044

# %% [markdown]
# Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_lr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 7.14623333e-01  8.28555885e-01  7.90760536e-01  8.10430907e-01
#  -1.01382961e+27]
# Mean Cross Validation Score: -2.0276592194420423e+26
# Difference between R2 score and Cross Validation score: 2.0276592194420424e+28

# %%
scores = cross_val_score(Rd, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Rd) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.71548825 0.82855503 0.79076588 0.81040673 0.69810948]
# Mean Cross Validation Score: 0.7686650723505142
# Difference between R2 score and Cross Validation score: 6.119888070025903

# %%
scores = cross_val_score(Dtr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Dtr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-2.93897459  0.78722196  0.75126235  0.82048568  0.55139372]
# Mean Cross Validation Score: -0.005722177593553002
# Difference between R2 score and Cross Validation score: 76.99710289682184

# %%
scores = cross_val_score(Rfr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Rfr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.13306438  0.87963004  0.86475714  0.90279991  0.80812559]
# Mean Cross Validation Score: 0.6644496598456134
# Difference between R2 score and Cross Validation score: 22.0935648211413

# %%
scores = cross_val_score(Svr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.70035336 0.83297187 0.81540962 0.8273227  0.75273654]
# Mean Cross Validation Score: 0.7857588181268435
# Difference between R2 score and Cross Validation score: 6.4980326399900035

# %%
scores = cross_val_score(Knn, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Knn) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.65727971 0.7564717  0.75846488 0.77316392 0.59369999]
# Mean Cross Validation Score: 0.7078160413503403
# Difference between R2 score and Cross Validation score: 6.129407103310502

# %% [raw]
# our best fit model is Rfr (RandomForestRegressor())

# %%
#GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
reg = RandomForestRegressor()

parameters = {
    "n_estimators": [100, 200, 300],
    "max_depth": [0, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}

grid = GridSearchCV(estimator=reg, param_grid=parameters, cv=5, n_jobs=-1)
grid.fit(X_reg_train, y_reg_train)

best_params = grid.best_params_
print("Best Parameters:", best_params)

score = grid.score(X_reg_test, y_reg_test)
print("Test Score:", score)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Test Score: 0.8875582241934578

# %%
Model = RandomForestRegressor(max_depth=10, max_features='auto', min_samples_leaf=2, min_samples_split=5, n_estimators=200)

# %%
Model.fit(X_reg_train, y_reg_train)
pred = Model.predict(X_reg_test)

print("R2_score:", r2_score(y_reg_test, pred))
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred)))
# Out:
# R2_score: 0.8883073780804751
# Mean Absolute Error: 0.5315430070145106
# Mean Squared Error: 0.4808571546984036
# Root Mean Squared Error: 0.6934386452299898

# %%
#Save the model for Task 1(Average Cost for two)
import pickle

filename = 'Zomato Restaurant Data Prediction.pkl'
pickle.dump(Model, open(filename, 'wb'))

# %%
LoadedModel_Task1 = pickle.load(open('Zomato Restaurant Data Prediction.pkl', 'rb'))
result = LoadedModel_Task1.score(X_reg_test, y_reg_test)
print(result * 100)
# Out:
# 88.83073780804752

# %%
Conclusion = pd.DataFrame([LoadedModel_Task1.predict(X_reg_test)[:],y_reg_test[:]],index = ["predicted","Original"])
Conclusion
# Out:
#                0         1         2         3         4         5     \
# predicted  8.677829  8.563646  8.564116  8.665281  6.636850  6.990004
# Original   8.879040  8.434327  8.193213  8.662391  7.368063  7.368063
#
#                6         7         8          9     ...      2560      2561  \
# predicted  8.550458  5.505105  6.265111  13.310591  ...  8.387442  6.953649
# Original   8.434327  5.313293  5.848035  13.572088  ...  8.879040  7.663094
#
#                2562       2563      2564      2565      2566      2567  \
# predicted  6.023853  11.336375  8.588270  8.118652  8.636208  8.593422
# Original   4.641589  10.772173  9.283178  7.937005  7.937005  8.662391
#
#                2568       2569
# predicted  8.308883  10.457633
# Original   8.434327  10.626586
#
# [2 rows x 2570 columns]

# %% [markdown]
# Regression  TASK 2 (Price range)

# %%
#Separating features and label
X_reg1 = df.drop("Price range",axis=1)
y_reg1= df["Price range"]

# %%
#Feature Scalling using standard scalarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_reg1 = pd.DataFrame(scaler.fit_transform(X_reg1), columns=X_reg1.columns)
X_reg1
# Out:
#       Restaurant Name  Country Code      City   Address  Locality Verbose  \
# 0            0.052689     11.390428 -0.498280  1.612139         -1.570067
# 1           -0.226145     11.390428 -0.498280  0.523697         -0.312136
# 2           -0.355245     11.390428 -0.381656 -0.040436         -1.163998
# 3            0.491312     11.390428 -0.381656  1.614327          0.473520
# 4            0.876496     11.390428 -0.381656  1.613889          0.473520
# ...               ...           ...       ...       ...               ...
# 8560        -0.674292     11.505165 -2.131029 -1.183147          1.391589
# 8561         1.656387     11.505165 -2.131029 -1.405912          1.475451
# 8562         0.847925     11.505165 -2.131029  0.285615          1.501934
# 8563         0.545809     11.505165 -2.131029 -0.366050          1.585796
# 8564         0.817766     11.505165 -2.131029  1.551305          1.585796
#
#       Longitude  Latitude  Cuisines  Average Cost for two   Currency  \
# ...

# %%
#checking variance inflation factor (vif)
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif = pd.DataFrame()
Vif['VIF Values'] = [variance_inflation_factor(X_reg1.values, i) for i in range(len(X_reg1.columns))]
Vif['Features'] = X_reg1.columns
Vif
# Out:
#     VIF Values              Features
# 0     1.009045       Restaurant Name
# 1    16.854956          Country Code
# 2     1.076606                  City
# 3     1.062654               Address
# 4     1.056343      Locality Verbose
# 5     8.594348             Longitude
# 6     8.723790              Latitude
# 7     1.024380              Cuisines
# 8     2.035844  Average Cost for two
# 9     1.594233              Currency
# 10    1.674647     Has Table booking
# 11    1.204067   Has Online delivery
# 12    1.014994     Is delivering now
# 13    3.485305      Aggregate rating
# 14    1.241685          Rating color
# 15    1.517244           Rating text
# 16    3.514700                 Votes
# 17   16.839914               Country

# %%
y_reg1.value_counts()
# Out:
# 1.000000    4289
# 1.259921    2827
# 1.442250    1052
# 1.587401     397
# Name: Price range, dtype: int64

# %% [markdown]
# modelling for regression

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding the best random state

MaxAccu = 0
MaxRs = 0

for i in range(1, 200):
    X_reg1_train, X_reg1_test, y_reg1_train, y_reg1_test = train_test_split(X_reg1, y_reg1, test_size=0.3, random_state=i)
    lr = LinearRegression()
    lr.fit(X_reg1_train, y_reg1_train)
    pred = lr.predict(X_reg1_test)
    acc = r2_score(y_reg1_test, pred)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRs = i

print("Maximum R2 score is", MaxAccu, "on Random State", MaxRs)
# Out:
# Maximum R2 score is 0.81439809781972 on Random State 33

# %%
X_reg1_train, X_reg1_test, y_reg1_train,y_reg1_test = train_test_split(X_reg1, y_reg1, test_size=0.3, random_state=33)

# %%
#modelling
#import liabraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
lr.fit(X_reg1_train,y_reg1_train)
pred_lr = lr.predict(X_reg1_test)
pred_train = lr.predict(X_reg1_train)

print("R2_score:",r2_score(y_reg1_test,pred_lr))
print("R2_score on training Data:",r2_score(y_reg1_train,pred_train)*100)
print ("MeanAbsoluteError:",mean_absolute_error(y_reg1_test,pred_lr))
print ("MeanSquaredError:",mean_squared_error(y_reg1_test,pred_lr))
print ("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_reg1_test,pred_lr)))
# Out:
# R2_score: 0.81439809781972
# R2_score on training Data: 79.7007148355072
# MeanAbsoluteError: 0.06764426131446469
# MeanSquaredError: 0.006563315692498222
# Root Mean Squared Error: 0.08101429313706454

# %%
Rd = Ridge()
Rd.fit(X_reg1_train, y_reg1_train)
pred_Rd = Rd.predict(X_reg1_test)
pred_train = Rd.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Rd))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Rd))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Rd)))
# Out:
# R2_score: 0.8143910694915834
# R2_score on training Data: 79.70070231506475
# Mean Absolute Error: 0.06764779518160169
# Mean Squared Error: 0.00656356423055634
# Root Mean Squared Error: 0.08101582703741497

# %%
Dtr = DecisionTreeRegressor()
Dtr.fit(X_reg1_train, y_reg1_train)
pred_Dtr = Dtr.predict(X_reg1_test)
pred_train = Dtr.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Dtr))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Dtr))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Dtr)))
# Out:
# R2_score: 0.9821866125024454
# R2_score on training Data: 1.0
# Mean Absolute Error: 0.003274808562959438
# Mean Squared Error: 0.0006299228850881529
# Root Mean Squared Error: 0.02509826458319684

# %%
Rfr = RandomForestRegressor()
Rfr.fit(X_reg1_train, y_reg1_train)
pred_Rfr = Rfr.predict(X_reg1_test)
pred_train = Rfr.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Rfr))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Rfr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Rfr)))
# Out:
# R2_score: 0.9892722079604856
# R2_score on training Data: 99.84547369699585
# Mean Absolute Error: 0.003953150833667889
# Mean Squared Error: 0.0003793597210572278
# Root Mean Squared Error: 0.019477158957538643

# %%
Svr = SVR()
Svr.fit(X_reg1_train, y_reg1_train)
pred_Svr = Svr.predict(X_reg1_test)
pred_train = Svr.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Svr))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Svr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Svr)))
# Out:
# R2_score: 0.9892722079604856
# R2_score on training Data: 86.99174060907318
# Mean Absolute Error: 0.057243626294115724
# Mean Squared Error: 0.0046630392797969685
# Root Mean Squared Error: 0.06828645019179844

# %%
Knn = KNeighborsRegressor()
Knn.fit(X_reg1_train, y_reg1_train)
pred_Knn = Knn.predict(X_reg1_test)
pred_train = Knn.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Knn))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Knn))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Knn)))
# Out:
# R2_score: 0.766638447937249
# R2_score on training Data: 84.13168597673335
# Mean Absolute Error: 0.06060466578365703
# Mean Squared Error: 0.008252208186915489
# Root Mean Squared Error: 0.09084166547854287

# %% [markdown]
# CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_lr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 6.98265197e-01  8.16654270e-01  7.75099256e-01  7.93449801e-01
#  -3.37682910e+25]
# Mean Cross Validation Score: -6.753658193783761e+24
# Difference between R2 score and Cross Validation score: 6.753658193783761e+26

# %%
scores = cross_val_score(Rd, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Rd) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.69830713 0.81665747 0.77509629 0.79348821 0.70095514]
# Mean Cross Validation Score: 0.7569008461075639
# Difference between R2 score and Cross Validation score: 5.749022338401943

# %%
scores = cross_val_score(Dtr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Dtr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.929739   0.95593368 1.         0.99886303 0.90416615]
# Mean Cross Validation Score: 0.957740370939349
# Difference between R2 score and Cross Validation score: 2.4446241563096383

# %%
scores = cross_val_score(Rfr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Rfr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.7965278  0.97978542 0.99988469 0.99955416 0.93155826]
# Mean Cross Validation Score: 0.9414620654655422
# Difference between R2 score and Cross Validation score: 4.781014249494342

# %%
scores = cross_val_score(Svr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.65979816 0.86965975 0.83191626 0.8698775  0.81047602]
# Mean Cross Validation Score: 0.8083455380842534
# Difference between R2 score and Cross Validation score: 5.978986773495787

# %%
scores = cross_val_score(Svr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.65979816 0.86965975 0.83191626 0.8698775  0.81047602]
# Mean Cross Validation Score: 0.8083455380842534
# Difference between R2 score and Cross Validation score: 5.978986773495787

# %%
scores = cross_val_score(Knn, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Knn) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.72135831 0.73982519 0.76358398 0.80273642 0.61136712]
# Mean Cross Validation Score: 0.7277742030617982
# Difference between R2 score and Cross Validation score: 3.8864244875450815

# %% [raw]
# our best fit model is Rfr (RandomForestRegressor())

# %% [markdown]
# HyperparameterTuning

# %%
#GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
reg1 = RandomForestRegressor()

parameters = {
    "n_estimators": [100, 200, 300],
    "max_depth": [0, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}

grid = GridSearchCV(estimator=reg1, param_grid=parameters, cv=5, n_jobs=-1)
grid.fit(X_reg1_train, y_reg1_train)

best_params = grid.best_params_
print("Best Parameters:", best_params)

score = grid.score(X_reg1_test, y_reg1_test)
print("Test Score:", score)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# Test Score: 0.9893292849910161

# %%
Model1 = RandomForestRegressor(max_depth=10, max_features='auto', min_samples_leaf=1, min_samples_split=2, n_estimators=200)

# %%
Model1.fit(X_reg1_train, y_reg1_train)
pred = Model1.predict(X_reg1_test)

print("R2_score:", r2_score(y_reg1_test, pred))
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred)))
# Out:
# R2_score: 0.9892920088537617
# Mean Absolute Error: 0.0039941979354534436
# Mean Squared Error: 0.00037865951533715017
# Root Mean Squared Error: 0.019459175607850147

# %%
#Save the model for Task 2(price range)
import pickle

filename = 'Zomato Restaurant Data Prediction.pkl'
pickle.dump(Model1, open(filename, 'wb'))

# %%
LoadedModel_Task2 = pickle.load(open('Zomato Restaurant Data Prediction.pkl', 'rb'))
result = LoadedModel_Task2.score(X_reg1_test, y_reg1_test)
print(result * 100)
# Out:
# 98.92920088537616

# %%
Conclusion = pd.DataFrame([LoadedModel_Task2.predict(X_reg1_test)[:],y_reg1_test[:]],index = ["predicted","Original"])
Conclusion
# Out:
#            0         1         2     3         4     5     6     7     \
# predicted   1.0  1.478529  1.071478   1.0  1.259921   1.0   1.0   1.0
# Original    1.0  1.442250  1.000000   1.0  1.259921   1.0   1.0   1.0
#
#                8         9     ...     2560      2561  2562      2563  \
# predicted  1.259921  1.259921  ...  1.44225  1.406406   1.0  1.587401
# Original   1.259921  1.259921  ...  1.44225  1.442250   1.0  1.587401
#
#                2564      2565  2566      2567  2568  2569
# predicted  1.259921  1.259921   1.0  1.000006   1.0   1.0
# Original   1.259921  1.259921   1.0  1.000000   1.0   1.0
#
# [2 rows x 2570 columns]
